# %% [markdown]
# # Python in Business / C01

# %% [markdown]
# ## Lecture

# %%
class Date:
    pass

def isLeap(year):
    if year % 400 == 0:
        return True
    elif (year % 4 == 0) and (year % 100 != 0):
        return True
    else:
        return False
    
def isValidDate(bday): # birthday is a yyyy/mm/dd string
    if (1 <= bday.year <= 3000) and (1 <= bday.month <= 12):
        daysInMonth = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
        if isLeap(year) == True:
            daysInMonth[1] = 29
        if 1 <= bday.day <= daysInMonth[bday.month - 1]:
            return True
    return False

def strToDate(birthday): # birthday is a yyyy/mm/dd string
    d = Date()
    year, month, day = birthday.split("/")
    d.year = int(year)
    d.month = int(month)
    d.day = int(day)
    return d

bdDict = dict()

while True:
    name = input("name: ")
    if(name == ""):
        break

    birthday = input("birthday (yyyy/mm/dd): ") # birthday is a string
    birthday = strToDate(birthday) # now birthday is a Date
    
    if isValidDate(birthday) == True:
        bdDict[name] = birthday # now the value of a dictionary entry is a Date
    else:
        print("bad date!")

    if birthday == "":
        break

print(bdDict) # what will be printed out?
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 39
#      36 birthday = input("birthday (yyyy/mm/dd): ") # birthday is a string
#      37 birthday = strToDate(birthday) # now birthday is a Date
# ---> 39 if isValidDate(birthday) == True:
#      40     bdDict[name] = birthday # now the value of a dictionary entry is a Date
#      41 else:
#
# Cell In[6], line 15, in isValidDate(bday)
#      13 if (1 <= bday.year <= 3000) and (1 <= bday.month <= 12):
#      14     daysInMonth = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
# ---> 15     if isLeap(year) == True:
#      16         daysInMonth[1] = 29
#      17     if 1 <= bday.day <= daysInMonth[bday.month - 1]:
#
# NameError: name 'year' is not defined

# %% [markdown]
# ## Homework / Self-practice

# %% [markdown]
# ## Homework / Counted

# %% [markdown]
# ***Exercise***
